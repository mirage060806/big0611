# %%
# 패키지(packages)
# : 관련 있는 모듈의 집합이다.

# %%
# 가상의 game 패키지 예
game/
    __init__.py
    sound/
        __init__.py
        echo.py
        wav.py
    graphic/
        __init__.py
        screen.py
        render.py
    play/
        __init__.py
        run.py
        test.py

# %%
# 패키지 만들기

# %%
# ㅣ스템 패스로 사용자 정의 패키지 추가
import sys
sys.path.append(r'C:\git\big0611\py\p04_머신딥러닝\ch01_문법정리\game')

# %%
# echo.py
# def echo_test():
#     print("echo")

# %%
# import 패키지명.하위패키지명.모듈명
import game.sound.echo
game.sound.echo.echo_test()
# Out:
# echo

# %%
# from 패키지명.하위패키지명 import 모듈명
from game.sound import echo
echo.echo_test()
# Out:
# echo

# %%
# From 패키지명.하위패키지명.모듈명 import 함수명
from game.sound.echo import echo_test
echo_test()
# Out:
# echo

# %%
# import a.b.c
# -> import할 때 마지막 항목인 c는 반드시 모듈 또는 패키지여야 한다.
import game
game.sound.echo.echo_test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import game
# ----> 2 game.sound.echo.echo_test()
#
# AttributeError: module 'game' has no attribute 'sound'

# %%
import game.sound.echo.echo_test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import game.sound.echo.echo_test
#
# ModuleNotFoundError: No module named 'game.sound.echo.echo_test'; 'game.sound.echo' is not a package

# %%
# __init__.py 파일의 용도
# 1. __init__.py 파일은 해당 디렉터리가 패키지의 일부임을 알려주는 역할을 한다.
# 2. python 3.3 버전부터는 __init__.py 파일이 없어도 패키지로 인식한다.
# 3. __init__.py 파일을 생성하는 것이 파이썬 커뮤니티의 일반적인 관례이므로 항상 만들어 주는 것이 좋다.
# 4. __init__.py 파일은 패키지 설정이나 초기화 코드를 포함할 수도 있다.

# %%
# 패키지 변수 및 함수 정의
# game 패키지의 __init__.py 파일에 공통 변수나 함수를 정의할 수 있다.

# %%
# C:/doit/game/__init__.py
# VERSION = 3.5

# def print_version_info():
#     print(f"The version of this game is {VERSION}.")

# %%
import game
print(game.VERSION)
game.print_version_info()
# Out:
# 3.5
# The version of this game is 3.5.
