# %% [markdown]
# # 코랩에서 구글 마운트
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # 반드시 프로젝트 디렉토리 내부에서 실행
# %cd /content/drive/MyDrive/{REPO_NAME}
#
# # 원격 저장소 URL에 토큰 적용 (토큰 세션 갱신 목적)
# !git remote set-url origin https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git
#
# # 최신 변경사항 Pull
# !git pull origin main

# %% [markdown]
# # 프로젝트 디렉토리로 이동
# %cd /content/drive/MyDrive/{REPO_NAME}
#
# # 1. 원격 저장소 인증 URL 설정
# !git remote set-url origin https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git
#
# # 2. 변경 파일 스테이징 및 커밋
# !git add .
# !git commit -m "Colab 작업 내용 커밋"
#
# # 3. 원격 저장소로 Push
# !git push origin main

# %% [markdown]
# # 데이터 타입
# ## 1. 기본 데이터 타입
# 1. 숫자: 정수(int), 실수(float)
# 2. 문자열(str): 'True', "10", '''문장''', """문장"""
# 3. 불(bool): True, False
# ### 예약어
# - 대소문자 구별한다.
# True, False
#
# ## 2. 컨터이너 타입
# 1. 리스트(list): [1, 2, 3, 2, 3], 순서(인덱스), 수정(추가, 삭제)
# 2. 튜플(tuple): (1, 2, 3, 2, 3), 순서(인덱스), 수정x
# 3. 세트(set): {1, 2, 3}, 순서(인덱스x)x, 수정, 중복x
# 4. 딕셔너리(dict): {'키':값, '2':3, '3':3}, 수정, 키는 중복x
#
#
# ## 타입 변환 함수
# int("10")
# float(10)
# bool('True')
# list((1, 2, 3))
# tuple()
# set()
# dict()

# %%
# shift+alt+↑,↓
color_list = ['red', 'green', 'blue']
color_tuple = ('red', 'green', 'blue')
color_set = {'red', 'green', 'blue'}
color_dict = {'1':'red', '2':'green', '3':'blue'}

# ctrl+alt+↑,↓ 또는 alt+클릭
print(type(color_list))
print(type(color_tuple))
print(type(color_set))
print(type(color_dict))
