# %%
# EDA(Exploratory Data Analysis, 탐색적 데이터 분석)
# : 데이터의 날것 그대로의 상태를 샅샅이 뜯어보며 특징을 파악하고 인사이트를 얻는 과정

import pandas as pd

data = {
    "고객ID": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010],
    "성별": ["남", "여", "여", "남", "여", "남", "남", "여", "남", "여"],
    "나이": [25, 32, 28, 41, 35, 22, 45, 30, 38, 27],
    "지역": ["서울", "부산", "서울", "대구", "인천", "서울", "부산", "대전", "서울", "인천"],
    "구매금액": [35000, 72000, 15000, 120000, 55000, 23000, 98000, 45000, 87000, 32000],
    "구매횟수": [2, 5, 1, 8, 4, 2, 6, 3, 5, 2],
    "회원등급": ["일반", "VIP", "일반", "VVIP", "VIP", "일반", "VIP", "일반", "VIP", "일반"],
    "만족도": [4, 5, 3, 5, 4, 2, 5, 4, 4, 3]
}

df = pd.DataFrame(data)

# %%
# 1단계: 데이터의 첫인상 확인하기 (구조 파악)
df.head()       # 상위 5개 데이터
# Out:
#    고객ID 성별  나이  지역    구매금액  구매횟수  회원등급  만족도
# 0  1001  남  25  서울   35000     2    일반    4
# 1  1002  여  32  부산   72000     5   VIP    5
# 2  1003  여  28  서울   15000     1    일반    3
# 3  1004  남  41  대구  120000     8  VVIP    5
# 4  1005  여  35  인천   55000     4   VIP    4

# %%
df.shape        # 행, 열 크기
# Out:
# (10, 8)

# %%
df.columns      # 열 이름
# Out:
# Index(['고객ID', '성별', '나이', '지역', '구매금액', '구매횟수', '회원등급', '만족도'], dtype='str')

# %%
# 2단계: 데이터의 건강 상태 체크하기 (결측치와 타입)
df.info()               # 각 열의 데이터 타입과 Non-Null 개수 확인
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객ID    10 non-null     int64
#  1   성별      10 non-null     str
#  2   나이      10 non-null     int64
#  3   지역      10 non-null     str
#  4   구매금액    10 non-null     int64
#  5   구매횟수    10 non-null     int64
#  6   회원등급    10 non-null     str
#  7   만족도     10 non-null     int64
# dtypes: int64(5), str(3)
# memory usage: 772.0 bytes

# %%
df.isnull().sum()       # 결측치가 열마다 몇 개씩 있는지 누적 합계 확인
# Out:
# 고객ID    0
# 성별      0
# 나이      0
# 지역      0
# 구매금액    0
# 구매횟수    0
# 회원등급    0
# 만족도     0
# dtype: int64

# %%
# 3단계: 요약 통계로 수치 훑어보기 (기술 통계)
df.describe()           # 수치형 데이터의 요약 통계량
# Out:
#              고객ID         나이           구매금액      구매횟수        만족도
# count    10.00000  10.000000      10.000000  10.00000  10.000000
# mean   1005.50000  32.300000   58200.000000   3.80000   3.900000
# std       3.02765   7.364328   34860.993802   2.20101   0.994429
# min    1001.00000  22.000000   15000.000000   1.00000   2.000000
# 25%    1003.25000  27.250000   32750.000000   2.00000   3.250000
# 50%    1005.50000  31.000000   50000.000000   3.50000   4.000000
# 75%    1007.75000  37.250000   83250.000000   5.00000   4.750000
# max    1010.00000  45.000000  120000.000000   8.00000   5.000000

# %%
df['성별'].value_counts()  # 범주형 데이터의 종류별 개수 (예: 남성 600명, 여성 400명)
# Out:
# 성별
# 남    5
# 여    5
# Name: count, dtype: int64

# %%
# 4단계: 시각화로 숨은 패턴 찾기 (시각적 탐색)
# - 숫자만 봐서는 모르는 데이터의 '분포'와 변수 간의 '관계'를 그래프로 시각화합니다.

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. 단일 변수 탐색: 고객들의 나이 분포는 어떨까? (히스토그램)
sns.histplot(df['나이'], kde=True)
plt.show()
# Out:
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2. 다변수 탐색: 나이와 구매금액은 어떤 관계가 있을까? (산점도)
sns.scatterplot(x='나이', y='구매금액', data=df)
plt.show()
# Out:
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45208 (\N{HANGUL SYLLABLE NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\git\big0611\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from font(s) DejaVu Sans.
# ...
